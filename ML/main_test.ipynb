# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
a = tf.Variable([[1.0, 2.0], [3.0, 4.0]])
plt.imshow(a.numpy())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a = tf.Variable([[3.0, 2.0], [1.0, 7.0]])
plt.imshow(a.numpy())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
